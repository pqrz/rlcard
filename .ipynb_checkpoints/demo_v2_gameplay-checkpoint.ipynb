# %%
# ! conda install pytorch torchvision torchaudio cpuonly -c pytorch

# %% [markdown]
# # Import

# %%
import os
import argparse

import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger

# %% [markdown]
# # Training

# %%
import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger


# Check whether gpu is available
device = get_device()

# Seed numpy, torch, random
set_seed(7)

# Make the environment with seed
env = rlcard.make("bridge", config={'seed': 7})

# Initialize the agent and use random agents as opponents
from rlcard.agents import DQNAgent
agent = DQNAgent(num_actions=env.num_actions,
                 state_shape=env.state_shape[0],
                 mlp_layers=[700 , 700],
                 device=device)

agents = [agent]
for _ in range(env.num_players):
    agents.append(RandomAgent(num_actions=env.num_actions))
env.set_agents(agents)

#for episode in range(2000):

for episode in range(10):
    #print('\n episode:', episode)
    trajectories, payoffs = env.run(is_training=True)
    #break
    # Training
    trajectories = reorganize(trajectories, payoffs)
    for ts in trajectories[0]:
        agent.feed(ts)
        #rl_loss = agent.train_rl()
        #sl_loss = agent.train_sl()
# Out:
# --> Running on the CPU
# C:\Users\ha.agarwal\Downloads\tarneeb_enviornment-main\tarneeb_clone_v01\rlcard\rlcard\agents\dqn_agent.py:198: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   state_batch, action_batch, reward_batch, next_state_batch, legal_actions_batch, done_batch = self.memory.sample()
# INFO - Step 100, rl-loss: 30.60272216796875
# INFO - Copied model parameters to target network.
# INFO - Step 1100, rl-loss: 10.1023225784301767
# INFO - Copied model parameters to target network.
# INFO - Step 2100, rl-loss: 8.2941398620605476
# INFO - Copied model parameters to target network.
# INFO - Step 3100, rl-loss: 3.4217917919158936
# INFO - Copied model parameters to target network.
# INFO - Step 4100, rl-loss: 9.3518791198730473
# INFO - Copied model parameters to target network.
# INFO - Step 5100, rl-loss: 8.3588294982910165
# INFO - Copied model parameters to target network.
# INFO - Step 6100, rl-loss: 5.4047493934631358
# INFO - Copied model parameters to target network.
# INFO - Step 7100, rl-loss: 5.1528754234313965
# INFO - Copied model parameters to target network.
# INFO - Step 8100, rl-loss: 11.414016723632812
# INFO - Copied model parameters to target network.
# INFO - Step 9100, rl-loss: 4.4642047882080085
# INFO - Copied model parameters to target network.
# INFO - Step 10100, rl-loss: 6.8197617530822755
# INFO - Copied model parameters to target network.
# INFO - Step 11100, rl-loss: 6.5070018768310555
# INFO - Copied model parameters to target network.
# INFO - Step 12100, rl-loss: 4.7718586921691895
# INFO - Copied model parameters to target network.
# INFO - Step 13100, rl-loss: 10.101676940917969
# INFO - Copied model parameters to target network.
# INFO - Step 14100, rl-loss: 4.5588235855102546
# INFO - Copied model parameters to target network.
# INFO - Step 14450, rl-loss: 3.9642677307128906

# %% [markdown]
# # Testing

# %%
# Simulation

def run_1_simulation():
    trajectories, payoffs = env.run()
    if payoffs[0] > payoffs[1]:
        return 0
    else:
        return 1

# %%
l = [run_1_simulation() for i in range(2000)] 

sum(l) / len(l)
# Out:
# 0.3315

# %%
1 - 0.277
# Out:
# 0.723

# %% [markdown]
# # Game Play

# %% [markdown]
# Play Game for 1 fateiyah

# %%
##### import os
import argparse

import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger
from rlcard.agents.human_agent_bridge import HumanAgentBridge

env2 = rlcard.make("bridge", config={'seed': 7})

agents = [
          #agent,
          RandomAgent(num_actions=env2.num_actions, verbose=True),
          RandomAgent(num_actions=env2.num_actions, verbose=True),
          RandomAgent(num_actions=env2.num_actions, verbose=True),
          HumanAgentBridge(num_actions=env2.num_actions, verbose=True)
         ]

env2.set_agents(agents)

_, payoffs = env2.run()
# Out:
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', 'TH', '3S', 'JS', 'QS']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '2H', '4H', '5H', '7H', '8H', '9H', 'JH', 'QH', 'KH', 'AH', '2S', '4S', '5S', '6S', '7S', '8S', '9S', 'TS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [0]
# 7. Bidding amount Rep:   []
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 0 0]
# 10. Contract Trump rep:  [0 0 0 0 0]
#
# Possible Legal Actions: ['Pass', '7_C', '7_D', '7_H', '7_S', '8_C', '8_D', '8_H', '8_S', '9_C', '9_D', '9_H', '9_S', '10_C', '10_D', '10_H', '10_S', '11_C', '11_D', '11_H', '11_S', '12_C', '12_D', '12_H', '12_S', '13_C', '13_D', '13_H', '13_S']
# Final Choice: 23
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '3H', '4H', '6H', '7H', '8H', 'TH', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [0]
# 7. Bidding amount Rep:   [22]
# 8. Last bid amount rep:  [22]
# 9. Contract Bid rep:	    [0 0 0 0 0 0 0 0]
# 10. Contract Trump rep:  [0 0 0 0 0]
#
# Possible Legal Actions: ['Pass', '10_C', '10_D', '10_H', '10_S', '11_C', '11_D', '11_H', '11_S', '12_C', '12_D', '12_H', '12_S', '13_C', '13_D', '13_H', '13_S']
# Final Choice: 11
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', '9H', 'TH', 'KH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [0]
# 7. Bidding amount Rep:   [46]
# 8. Last bid amount rep:  [10]
# 9. Contract Bid rep:	    [0 0 0 0 0 0 0 0]
# 10. Contract Trump rep:  [0 0 0 0 0]
#
# Possible Legal Actions: ['Pass', '12_C', '12_D', '12_H', '12_S', '13_C', '13_D', '13_H', '13_S']
# Final Choice: 5
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '7H', '9H', 'TH', 'JH', 'QH', 'KH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [0]
# 7. Bidding amount Rep:   [76]
# 8. Last bid amount rep:  [4]
# 9. Contract Bid rep:	    [0 0 0 0 0 0 0 0]
# 10. Contract Trump rep:  [0 0 0 0 0]
#
# Possible Legal Actions: ['Pass', '13_C', '13_D', '13_H', '13_S']
# >> You choose action (integer): 0
# Final Choice: 35
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', 'TH', '3S', 'JS', 'QS']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '2H', '4H', '5H', '7H', '8H', '9H', 'JH', 'QH', 'KH', 'AH', '2S', '4S', '5S', '6S', '7S', '8S', '9S', 'TS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [0]
# 7. Bidding amount Rep:   [76]
# 8. Last bid amount rep:  [34]
# 9. Contract Bid rep:	    [0 0 0 0 0 0 0 0]
# 10. Contract Trump rep:  [0 0 0 0 0]
#
# Possible Legal Actions: ['Pass', '13_C', '13_D', '13_H', '13_S']
# Final Choice: 20
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '3H', '4H', '6H', '7H', '8H', 'TH', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [0]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  [19]
# 9. Contract Bid rep:	    [0 0 0 0 0 0 0 0]
# 10. Contract Trump rep:  [0 0 0 0 0]
#
# Possible Legal Actions: ['Pass']
# Final Choice: 35
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', '9H', 'TH', 'KH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [0]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  [34]
# 9. Contract Bid rep:	    [0 0 0 0 0 0 0 0]
# 10. Contract Trump rep:  [0 0 0 0 0]
#
# Possible Legal Actions: ['Pass']
# Final Choice: 35
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '7H', '9H', 'TH', 'JH', 'QH', 'KH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [0]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  [34]
# 9. Contract Bid rep:	    [0 0 0 0 0 0 0 0]
# 10. Contract Trump rep:  [0 0 0 0 0]
#
# Possible Legal Actions: ['Pass']
# >> You choose action (integer): 0
# Final Choice: 35
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', 'TH', '3S', 'JS', 'QS']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '2H', '4H', '5H', '7H', '8H', '9H', 'JH', 'QH', 'KH', 'AH', '2S', '4S', '5S', '6S', '7S', '8S', '9S', 'TS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  [34]
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [3H, 5D, 4D, TC, JS, QS, 3S, 6H, 8D, 7C, 4C, QD, TH]
# Final Choice: 70
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:			    ['TH']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '3H', '4H', '6H', '7H', '8H', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [9H, 5H, KH]
# Final Choice: 73
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    ['TH', 'KH']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', '9H', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JH, 7H, QH]
# Final Choice: 67
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:			    ['TH', 'KH', '7H']
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '9H', 'JH', 'QH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [2H, 8H, 4H, AH]
# >> You choose action (integer): 0
# Final Choice: 62
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:			    ['TH', 'KH', '7H', '2H']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '3H', '4H', '6H', '8H', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [5S, 9H, KS, KC, 5H, KD, 9C, 8C, 2S, 5C, 2D, 4S]
# Final Choice: 86
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', '7D', 'TD', 'AD', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    ['KS']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '3H', '4H', '5H', '6H', '8H', '9H', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [8S, AS, TS, 9S, 6S]
# Final Choice: 81
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:			    ['KS', '8S']
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '9H', 'JH', 'QH', '2S', '3S', '4S', '5S', '6S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [7S]
# >> You choose action (integer): 0
# Final Choice: 80
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', '3S', 'JS', 'QS']
# 2. Pile Rep:			    ['KS', '8S', '7S']
# 3. Other Player Rep:	    ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '4H', '5H', '8H', '9H', 'JH', 'QH', 'AH', '2S', '4S', '5S', '6S', '9S', 'TS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JS, QS, 3S]
# Final Choice: 76
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', '2S', '4S', '5S']
# 2. Pile Rep:			    ['3S', 'KS', '8S', '7S']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '3H', '4H', '6H', '8H', 'JH', 'QH', 'AH', '6S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [5S, 9H, KC, 5H, KD, 9C, 8C, 2S, 5C, 2D, 4S]
# Final Choice: 65
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', '7D', 'TD', 'AD', 'JH', 'QH', '6S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    ['5H']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '3H', '4H', '6H', '8H', '9H', 'AH', '2S', '4S', '5S', 'JS', 'QS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JH, QH]
# Final Choice: 72
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '4H', '8H', 'AH']
# 2. Pile Rep:			    ['5H', 'QH']
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '6H', '9H', 'JH', '2S', '4S', '5S', '6S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [8H, 4H, AH]
# >> You choose action (integer): 0
# Final Choice: 68
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', 'JS', 'QS']
# 2. Pile Rep:			    ['5H', 'QH', '8H']
# 3. Other Player Rep:	    ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '4H', '9H', 'JH', 'AH', '2S', '4S', '5S', '6S', '9S', 'TS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [3H, 6H]
# Final Choice: 66
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', '7D', 'TD', 'AD', 'JH', '6S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    ['6H', '5H', 'QH', '8H']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '3H', '4H', '9H', 'AH', '2S', '4S', '5S', 'JS', 'QS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [3D, AD, TD, JH, AC, AS, TS, 9S, 6S, 7D]
# Final Choice: 87
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '4H', 'AH']
# 2. Pile Rep:			    ['AS']
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '9H', 'JH', '2S', '4S', '5S', '6S', '9S', 'TS', 'JS', 'QS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [4H, AH]
# >> You choose action (integer): 0
# Final Choice: 64
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', 'JS', 'QS']
# 2. Pile Rep:			    ['AS', '4H']
# 3. Other Player Rep:	    ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '9H', 'JH', 'AH', '2S', '4S', '5S', '6S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JS, QS]
# Final Choice: 85
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2D', 'KD', '9H', '2S', '4S', '5S']
# 2. Pile Rep:			    ['QS', 'AS', '4H']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '3H', 'JH', 'AH', '6S', '9S', 'TS', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [5S, 2S, 4S]
# Final Choice: 78
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', 'AH']
# 2. Pile Rep:			    ['QS', '5S', 'AS', '4H']
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '9H', 'JH', '2S', '4S', '6S', '9S', 'TS', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JD, 6C, 2C, QC, JC, 6D, 9D, AH, 3C]
# >> You choose action (integer): 0
# Final Choice: 58
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', 'JS']
# 2. Pile Rep:			    ['JD']
# 3. Other Player Rep:	    ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'KD', 'AD', '9H', 'JH', 'AH', '2S', '4S', '6S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [5D, 4D, 8D, QD]
# Final Choice: 51
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2D', 'KD', '9H', '2S', '4S']
# 2. Pile Rep:			    ['4D', 'JD']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '5D', '6D', '7D', '8D', '9D', 'TD', 'QD', 'AD', '3H', 'JH', 'AH', '6S', '9S', 'TS', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [KD, 2D]
# Final Choice: 60
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', '7D', 'TD', 'AD', 'JH', '6S', '9S', 'TS']
# 2. Pile Rep:			    ['4D', 'KD', 'JD']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '5D', '6D', '8D', '9D', 'QD', '3H', '9H', 'AH', '2S', '4S', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [3D, AD, TD, 7D]
# Final Choice: 61
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', '7D', 'TD', 'JH', '6S', '9S', 'TS']
# 2. Pile Rep:			    ['4D', 'KD', 'AD', 'JD']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '5D', '6D', '8D', '9D', 'QD', '3H', '9H', 'AH', '2S', '4S', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [3D, TD, JH, AC, TS, 9S, 6S, 7D]
# Final Choice: 54
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'AH']
# 2. Pile Rep:			    ['7D']
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '5D', '8D', 'TD', 'QD', '3H', '9H', 'JH', '2S', '4S', '6S', '9S', 'TS', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [6D, 9D]
# >> You choose action (integer): 0
# Final Choice: 53
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', 'TC', '5D', '8D', 'QD', '3H', 'JS']
# 2. Pile Rep:			    ['7D', '6D']
# 3. Other Player Rep:	    ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '9D', 'TD', '9H', 'JH', 'AH', '2S', '4S', '6S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [5D, 8D, QD]
# Final Choice: 52
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2D', '9H', '2S', '4S']
# 2. Pile Rep:			    ['5D', '7D', '6D']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '8D', '9D', 'TD', 'QD', '3H', 'JH', 'AH', '6S', '9S', 'TS', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [2D]
# Final Choice: 49
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', 'TD', 'JH', '6S', '9S', 'TS']
# 2. Pile Rep:			    ['5D', '2D', '7D', '6D']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '8D', '9D', 'QD', '3H', '9H', 'AH', '2S', '4S', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [3D, TD, JH, AC, TS, 9S, 6S]
# Final Choice: 50
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '9D', 'AH']
# 2. Pile Rep:			    ['3D']
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '8D', 'TD', 'QD', '3H', '9H', 'JH', '2S', '4S', '6S', '9S', 'TS', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [9D]
# >> You choose action (integer): 0
# Final Choice: 56
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', 'TC', '8D', 'QD', '3H', 'JS']
# 2. Pile Rep:			    ['3D', '9D']
# 3. Other Player Rep:	    ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', 'TD', '9H', 'JH', 'AH', '2S', '4S', '6S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [8D, QD]
# Final Choice: 59
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '9H', '2S', '4S']
# 2. Pile Rep:			    ['QD', '3D', '9D']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '8D', 'TD', '3H', 'JH', 'AH', '6S', '9S', 'TS', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [9H]
# Final Choice: 69
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2S', '4S']
# 2. Pile Rep:			    ['QD', '9H', '3D', '9D']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '8D', 'TD', '3H', 'JH', 'AH', '6S', '9S', 'TS', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [KC, 9C, 8C, 2S, 5C, 4S]
# Final Choice: 47
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', 'TD', 'JH', '6S', '9S', 'TS']
# 2. Pile Rep:			    ['KC']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', '8D', '3H', 'AH', '2S', '4S', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [AC]
# Final Choice: 48
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', 'AH']
# 2. Pile Rep:			    ['KC', 'AC']
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', '8D', 'TD', '3H', 'JH', '2S', '4S', '6S', '9S', 'TS', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [6C, 2C, QC, JC, 3C]
# >> You choose action (integer): 0
# Final Choice: 40
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', 'TC', '8D', '3H', 'JS']
# 2. Pile Rep:			    ['KC', 'AC', '6C']
# 3. Other Player Rep:	    ['2C', '3C', '5C', '8C', '9C', 'JC', 'QC', 'TD', 'JH', 'AH', '2S', '4S', '6S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [TC, 7C, 4C]
# Final Choice: 44
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['TD', 'JH', '6S', '9S', 'TS']
# 2. Pile Rep:			    ['TC', 'KC', 'AC', '6C']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '7C', '8C', '9C', 'JC', 'QC', '8D', '3H', 'AH', '2S', '4S', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [TD, JH, TS, 9S, 6S]
# Final Choice: 79
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', 'JC', 'QC', 'AH']
# 2. Pile Rep:			    ['6S']
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', '8D', 'TD', '3H', 'JH', '2S', '4S', '9S', 'TS', 'JS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [AH]
# >> You choose action (integer): 0
# Final Choice: 74
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', '8D', '3H', 'JS']
# 2. Pile Rep:			    ['6S', 'AH']
# 3. Other Player Rep:	    ['2C', '3C', '5C', '8C', '9C', 'JC', 'QC', 'TD', 'JH', '2S', '4S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JS]
# Final Choice: 84
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', '2S', '4S']
# 2. Pile Rep:			    ['JS', '6S', 'AH']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '7C', 'JC', 'QC', '8D', 'TD', '3H', 'JH', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [2S, 4S]
# Final Choice: 75
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', 'JC', 'QC']
# 2. Pile Rep:			    ['JS', '2S', '6S', 'AH']
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', '8D', 'TD', '3H', 'JH', '4S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [2C, QC, JC, 3C]
# >> You choose action (integer): 0
# Final Choice: 36
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '7C', '8D', '3H']
# 2. Pile Rep:			    ['2C']
# 3. Other Player Rep:	    ['3C', '5C', '8C', '9C', 'JC', 'QC', 'TD', 'JH', '4S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [7C, 4C]
# Final Choice: 41
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', '4S']
# 2. Pile Rep:			    ['7C', '2C']
# 3. Other Player Rep:	    ['3C', '4C', 'JC', 'QC', '8D', 'TD', '3H', 'JH', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [9C, 8C, 5C]
# Final Choice: 39
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['TD', 'JH', '9S', 'TS']
# 2. Pile Rep:			    ['7C', '5C', '2C']
# 3. Other Player Rep:	    ['3C', '4C', '8C', '9C', 'JC', 'QC', '8D', '3H', '4S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JH]
# Final Choice: 71
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['TD', '9S', 'TS']
# 2. Pile Rep:			    ['7C', '5C', 'JH', '2C']
# 3. Other Player Rep:	    ['3C', '4C', '8C', '9C', 'JC', 'QC', '8D', '3H', '4S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [TD, TS, 9S]
# Final Choice: 83
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C', 'JC', 'QC']
# 2. Pile Rep:			    ['TS']
# 3. Other Player Rep:	    ['4C', '8C', '9C', '8D', 'TD', '3H', '4S', '9S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [QC, JC, 3C]
# >> You choose action (integer): 0
# Final Choice: 46
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '8D', '3H']
# 2. Pile Rep:			    ['TS', 'QC']
# 3. Other Player Rep:	    ['3C', '8C', '9C', 'JC', 'TD', '4S', '9S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [3H]
# Final Choice: 63
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8C', '9C', '4S']
# 2. Pile Rep:			    ['3H', 'TS', 'QC']
# 3. Other Player Rep:	    ['3C', '4C', 'JC', '8D', 'TD', '9S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [4S]
# Final Choice: 77
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C', '8D']
# 2. Pile Rep:			    ['3H', '4S', 'TS', 'QC']
# 3. Other Player Rep:	    ['3C', '8C', '9C', 'JC', 'TD', '9S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [8D, 4C]
# Final Choice: 55
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8C', '9C']
# 2. Pile Rep:			    ['8D']
# 3. Other Player Rep:	    ['3C', '4C', 'JC', 'TD', '9S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [9C, 8C]
# Final Choice: 43
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['TD', '9S']
# 2. Pile Rep:			    ['8D', '9C']
# 3. Other Player Rep:	    ['3C', '4C', '8C', 'JC']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [TD]
# Final Choice: 57
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C', 'JC']
# 2. Pile Rep:			    ['8D', '9C', 'TD']
# 3. Other Player Rep:	    ['4C', '8C', '9S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JC, 3C]
# >> You choose action (integer): 0
# Final Choice: 45
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['9S']
# 2. Pile Rep:			    ['8D', '9C', 'TD', 'JC']
# 3. Other Player Rep:	    ['3C', '4C', '8C']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [9S]
# Final Choice: 82
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C']
# 2. Pile Rep:			    ['9S']
# 3. Other Player Rep:	    ['4C', '8C']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [3C]
# >> You choose action (integer): 0
# Final Choice: 37
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4C']
# 2. Pile Rep:			    ['9S', '3C']
# 3. Other Player Rep:	    ['8C']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [1 0 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [4C]
# Final Choice: 38
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8C']
# 2. Pile Rep:			    ['4C', '9S', '3C']
# 3. Other Player Rep:	    []
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [8C]
# Final Choice: 42

# %%
if payoffs[0] > payoffs[1]:
    print('Your Team: Won')
else:
    print('Your Team: Lose')
# Out:
# Your Team: Lose
