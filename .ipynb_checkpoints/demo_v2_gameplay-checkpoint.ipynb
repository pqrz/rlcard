# %%
# ! conda install pytorch torchvision torchaudio cpuonly -c pytorch

# %% [markdown]
# # Import

# %%
import os
import argparse

import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger

# %% [markdown]
# # Training

# %%
import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger


# Check whether gpu is available
device = get_device()

# Seed numpy, torch, random
set_seed(7)

# Make the environment with seed
env = rlcard.make("bridge", config={'seed': 7})

# Initialize the agent and use random agents as opponents
from rlcard.agents import DQNAgent
agent = DQNAgent(num_actions=env.num_actions,
                 state_shape=env.state_shape[0],
                 mlp_layers=[700 , 700],
                 device=device)

agents = [agent]
for _ in range(env.num_players):
    agents.append(RandomAgent(num_actions=env.num_actions))
env.set_agents(agents)

for episode in range(2000):
    #for episode in range(100):
    #print('\n episode:', episode)
    trajectories, payoffs = env.run(is_training=True)
    #break
    # Training
    trajectories = reorganize(trajectories, payoffs)
    for ts in trajectories[0]:
        agent.feed(ts)
        #rl_loss = agent.train_rl()
        #sl_loss = agent.train_sl()
# Out:
# --> Running on the CPU
# INFO - Step 100, rl-loss: 30.523998260498047
# INFO - Copied model parameters to target network.
# INFO - Step 1100, rl-loss: 9.61518096923828173
# INFO - Copied model parameters to target network.
# INFO - Step 1449, rl-loss: 9.0264568328857427

# %% [markdown]
# # Testing

# %%
# Simulation

def run_1_simulation():
    trajectories, payoffs = env.run()
    if payoffs[0] > payoffs[1]:
        return 0
    else:
        return 1

# %%
l = [run_1_simulation() for i in range(2000)] 

sum(l) / len(l)

# %%
1 - sum(l) / len(l)

# %% [markdown]
# # Game Play

# %% [markdown]
# Play Game for 1 fateiyah

# %%
##### import os
import argparse

import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger
from rlcard.agents.human_agent_bridge import HumanAgentBridge

env2 = rlcard.make("bridge", config={'seed': 7})

agents = [
          agent,
          #RandomAgent(num_actions=env2.num_actions, verbose=True),
          RandomAgent(num_actions=env2.num_actions, verbose=True),
          RandomAgent(num_actions=env2.num_actions, verbose=True),
          HumanAgentBridge(num_actions=env2.num_actions, verbose=True)
         ]

env2.set_agents(agents)

_, payoffs = env2.run()
# Out:
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '3H', '4H', '6H', '7H', '8H', 'TH', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [0]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  [19]
# 9. Contract Bid rep:	    [0 0 0 0 0 0 0 0]
# 10. Contract Trump rep:  [0 0 0 0 0]
#
# Possible Legal Actions: ['Pass']
# Final Choice: 35
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', '9H', 'TH', 'KH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [0]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  [34]
# 9. Contract Bid rep:	    [0 0 0 0 0 0 0 0]
# 10. Contract Trump rep:  [0 0 0 0 0]
#
# Possible Legal Actions: ['Pass']
# Final Choice: 35
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:			    []
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '7H', '9H', 'TH', 'JH', 'QH', 'KH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [0]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  [34]
# 9. Contract Bid rep:	    [0 0 0 0 0 0 0 0]
# 10. Contract Trump rep:  [0 0 0 0 0]
#
# Possible Legal Actions: ['Pass']
# >> You choose action (integer): 0
# Final Choice: 35
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:			    ['3H']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '4H', '6H', '7H', '8H', 'TH', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [9H, 5H, KH]
# Final Choice: 73
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    ['3H', 'KH']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '4H', '5H', '6H', '8H', '9H', 'TH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JH, 7H, QH]
# Final Choice: 72
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:			    ['3H', 'KH', 'QH']
# 3. Other Player Rep:	    ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '5H', '6H', '7H', '9H', 'TH', 'JH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [2H, 8H, 4H, AH]
# >> You choose action (integer): 0
# Final Choice: 62
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:			    ['3H', 'KH', 'QH', '2H']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '4H', '6H', '7H', '8H', 'TH', 'JH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [5S, 9H, KS, KC, 5H, KD, 9C, 8C, 2S, 5C, 2D, 4S]
# Final Choice: 39
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    ['5C']
# 3. Other Player Rep:	    ['2C', '3C', '4C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '4H', '5H', '6H', '8H', '9H', 'TH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [AC]
# Final Choice: 48
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:			    ['5C', 'AC']
# 3. Other Player Rep:	    ['4C', '7C', '8C', '9C', 'TC', 'KC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '5H', '6H', '7H', '9H', 'TH', 'JH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [6C, 2C, QC, JC, 3C]
# >> You choose action (integer): 0
# Final Choice: 40
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['3D', '7D', 'TD', 'AD', '7H', 'JH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    ['4C', '5C', 'AC', '6C']
# 3. Other Player Rep:	    ['2C', '3C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '4H', '5H', '6H', '8H', '9H', 'TH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [3D, AD, TD, JH, 8S, AS, TS, 9S, 6S, 7H, 7D]
# Final Choice: 50
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', 'JC', 'QC', '6D', '9D', 'JD', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:			    ['3D']
# 3. Other Player Rep:	    ['7C', '8C', '9C', 'TC', 'KC', '2D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '5H', '6H', '7H', '9H', 'TH', 'JH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JD, 6D, 9D]
# >> You choose action (integer): 0
# Final Choice: 58
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8C', '9C', 'KC', '2D', 'KD', '5H', '9H', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:			    ['8D', '3D', 'JD']
# 3. Other Player Rep:	    ['2C', '3C', '7C', 'TC', 'JC', 'QC', '4D', '5D', '6D', '7D', '9D', 'TD', 'QD', 'AD', '4H', '6H', '7H', '8H', 'TH', 'JH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [KD, 2D]
# Final Choice: 49
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['2C', '3C', 'JC', 'QC', '6D', '9D', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:			    ['8D', '2D', '3D', 'JD']
# 3. Other Player Rep:	    ['7C', '8C', '9C', 'TC', 'KC', '4D', '5D', '7D', 'TD', 'QD', 'KD', 'AD', '5H', '6H', '7H', '9H', 'TH', 'JH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [2C, 8H, 4H, QC, JC, 6D, 9D, AH, 7S, 3C]
# >> You choose action (integer): 0
# Final Choice: 36
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8C', '9C', 'KC', 'KD', '5H', '9H', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:			    ['TC', '2C']
# 3. Other Player Rep:	    ['3C', '7C', 'JC', 'QC', '4D', '5D', '6D', '7D', '9D', 'TD', 'QD', 'AD', '4H', '6H', '7H', '8H', 'TH', 'JH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [KC, 9C, 8C]
# Final Choice: 47
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['7D', 'TD', 'AD', '7H', 'JH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    ['TC', 'KC', '2C']
# 3. Other Player Rep:	    ['3C', '7C', '8C', '9C', 'JC', 'QC', '4D', '5D', '6D', '9D', 'QD', 'KD', '4H', '5H', '6H', '8H', '9H', 'TH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JH, 7H]
# Final Choice: 71
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['7D', 'TD', 'AD', '7H', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    ['TC', 'KC', 'JH', '2C']
# 3. Other Player Rep:	    ['3C', '7C', '8C', '9C', 'JC', 'QC', '4D', '5D', '6D', '9D', 'QD', 'KD', '4H', '5H', '6H', '8H', '9H', 'TH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [AD, TD, 8S, AS, TS, 9S, 6S, 7H, 7D]
# Final Choice: 54
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C', 'JC', 'QC', '6D', '9D', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:			    ['7D']
# 3. Other Player Rep:	    ['7C', '8C', '9C', '4D', '5D', 'TD', 'QD', 'KD', 'AD', '5H', '6H', '7H', '9H', 'TH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [6D, 9D]
# >> You choose action (integer): 0
# Final Choice: 53
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8C', '9C', 'KD', '5H', '9H', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:			    ['5D', '7D', '6D']
# 3. Other Player Rep:	    ['3C', '7C', 'JC', 'QC', '4D', '9D', 'TD', 'QD', 'AD', '4H', '6H', '7H', '8H', 'TH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [KD]
# Final Choice: 60
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8C', '9C', '5H', '9H', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:			    ['5D', 'KD', '7D', '6D']
# 3. Other Player Rep:	    ['3C', '7C', 'JC', 'QC', '4D', '9D', 'TD', 'QD', 'AD', '4H', '6H', '7H', '8H', 'TH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [5S, 9H, KS, 5H, 9C, 8C, 2S, 4S]
# Final Choice: 86
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['TD', 'AD', '7H', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:			    ['KS']
# 3. Other Player Rep:	    ['3C', '7C', '8C', '9C', 'JC', 'QC', '4D', '9D', 'QD', '4H', '5H', '6H', '8H', '9H', 'TH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [8S, AS, TS, 9S, 6S]
# Final Choice: 87
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C', 'JC', 'QC', '9D', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:			    ['KS', 'AS']
# 3. Other Player Rep:	    ['7C', '8C', '9C', '4D', 'TD', 'QD', 'AD', '5H', '6H', '7H', '9H', 'TH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [7S]
# >> You choose action (integer): 0
# Final Choice: 80
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['TD', 'AD', '7H', '6S', '8S', '9S', 'TS']
# 2. Pile Rep:			    ['JS', 'KS', 'AS', '7S']
# 3. Other Player Rep:	    ['3C', '7C', '8C', '9C', 'JC', 'QC', '4D', '9D', 'QD', '4H', '5H', '6H', '8H', '9H', 'TH', 'AH', '2S', '3S', '4S', '5S', 'QS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [AD, TD, 8S, TS, 9S, 6S, 7H]
# Final Choice: 79
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C', 'JC', 'QC', '9D', '4H', '8H', 'AH']
# 2. Pile Rep:			    ['6S']
# 3. Other Player Rep:	    ['7C', '8C', '9C', '4D', 'TD', 'QD', 'AD', '5H', '6H', '7H', '9H', 'TH', '2S', '3S', '4S', '5S', '8S', '9S', 'TS', 'QS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [8H, 4H, AH]
# >> You choose action (integer): 0
# Final Choice: 68
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8C', '9C', '5H', '9H', '2S', '4S', '5S']
# 2. Pile Rep:			    ['QS', '6S', '8H']
# 3. Other Player Rep:	    ['3C', '7C', 'JC', 'QC', '4D', '9D', 'TD', 'QD', 'AD', '4H', '6H', '7H', 'TH', 'AH', '3S', '8S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [5S, 2S, 4S]
# Final Choice: 75
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C', 'JC', 'QC', '9D', '4H', 'AH']
# 2. Pile Rep:			    ['QS', '2S', '6S', '8H']
# 3. Other Player Rep:	    ['7C', '8C', '9C', '4D', 'TD', 'QD', 'AD', '5H', '6H', '7H', '9H', 'TH', '3S', '4S', '5S', '8S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [4H, QC, JC, 9D, AH, 3C]
# >> You choose action (integer): 0
# Final Choice: 64
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8C', '9C', '5H', '9H', '4S', '5S']
# 2. Pile Rep:			    ['TH', '4H']
# 3. Other Player Rep:	    ['3C', '7C', 'JC', 'QC', '4D', '9D', 'TD', 'QD', 'AD', '6H', '7H', 'AH', '3S', '8S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [9H, 5H]
# Final Choice: 69
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['TD', 'AD', '7H', '8S', '9S', 'TS']
# 2. Pile Rep:			    ['TH', '9H', '4H']
# 3. Other Player Rep:	    ['3C', '7C', '8C', '9C', 'JC', 'QC', '4D', '9D', 'QD', '5H', '6H', 'AH', '3S', '4S', '5S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [7H]
# Final Choice: 67
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8C', '9C', '5H', '4S', '5S']
# 2. Pile Rep:			    ['7C']
# 3. Other Player Rep:	    ['3C', 'JC', 'QC', '4D', '9D', 'TD', 'QD', 'AD', '6H', 'AH', '3S', '8S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [9C, 8C]
# Final Choice: 43
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['TD', 'AD', '8S', '9S', 'TS']
# 2. Pile Rep:			    ['7C', '9C']
# 3. Other Player Rep:	    ['3C', '8C', 'JC', 'QC', '4D', '9D', 'QD', '5H', '6H', 'AH', '3S', '4S', '5S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [AD, TD, 8S, TS, 9S]
# Final Choice: 57
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C', 'JC', 'QC', '9D', 'AH']
# 2. Pile Rep:			    ['7C', '9C', 'TD']
# 3. Other Player Rep:	    ['8C', '4D', 'QD', 'AD', '5H', '6H', '3S', '4S', '5S', '8S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [QC, JC, 3C]
# >> You choose action (integer): 0
# Final Choice: 46
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C', 'JC', '9D', 'AH']
# 2. Pile Rep:			    ['7C', '9C', 'TD', 'QC']
# 3. Other Player Rep:	    ['8C', '4D', 'QD', 'AD', '5H', '6H', '3S', '4S', '5S', '8S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [JC, 9D, AH, 3C]
# >> You choose action (integer): 0
# Final Choice: 45
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8C', '5H', '4S', '5S']
# 2. Pile Rep:			    ['6H', 'JC']
# 3. Other Player Rep:	    ['3C', '4D', '9D', 'QD', 'AD', 'AH', '3S', '8S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [8C]
# Final Choice: 42
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['AD', '8S', '9S', 'TS']
# 2. Pile Rep:			    ['6H', '8C', 'JC']
# 3. Other Player Rep:	    ['3C', '4D', '9D', 'QD', '5H', 'AH', '3S', '4S', '5S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [AD, 8S, TS, 9S]
# Final Choice: 61
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['5H', '4S', '5S']
# 2. Pile Rep:			    ['QD']
# 3. Other Player Rep:	    ['3C', '4D', '9D', 'AH', '3S', '8S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [5H]
# Final Choice: 65
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['8S', '9S', 'TS']
# 2. Pile Rep:			    ['QD', '5H']
# 3. Other Player Rep:	    ['3C', '4D', '9D', 'AH', '3S', '4S', '5S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [8S, TS, 9S]
# Final Choice: 81
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C', '9D', 'AH']
# 2. Pile Rep:			    ['QD', '5H', '8S']
# 3. Other Player Rep:	    ['4D', '3S', '4S', '5S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [9D]
# >> You choose action (integer): 0
# Final Choice: 56
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4S', '5S']
# 2. Pile Rep:			    ['QD', '5H', '8S', '9D']
# 3. Other Player Rep:	    ['3C', '4D', 'AH', '3S', '9S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [5S, 4S]
# Final Choice: 78
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['9S', 'TS']
# 2. Pile Rep:			    ['5S']
# 3. Other Player Rep:	    ['3C', '4D', 'AH', '3S', '4S']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [TS, 9S]
# Final Choice: 82
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C', 'AH']
# 2. Pile Rep:			    ['5S', '9S']
# 3. Other Player Rep:	    ['4D', '3S', '4S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [AH]
# >> You choose action (integer): 0
# Final Choice: 74
#
# -------------- STATE / Human Agent  --------------
# 1. Your Hand Rep:	    ['3C']
# 2. Pile Rep:			    ['3S', '5S', '9S', 'AH']
# 3. Other Player Rep:	    ['4D', '4S', 'TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 0 1]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [3C]
# >> You choose action (integer): 0
# Final Choice: 37
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['4S']
# 2. Pile Rep:			    ['4D', '3C']
# 3. Other Player Rep:	    ['TS']
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 1 0 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [4S]
# Final Choice: 77
#
# -------------- STATE / Random Agent --------------
# 1. Your Hand Rep:	    ['TS']
# 2. Pile Rep:			    ['4D', '4S', '3C']
# 3. Other Player Rep:	    []
# 4. Highest Bidder:	    [1 0 0 0]
# 5. Current Player:	    [0 0 1 0]
# 6. Is Bidding phase:	    [1]
# 7. Bidding amount Rep:   [19]
# 8. Last bid amount rep:  []
# 9. Contract Bid rep:	    [0 0 0 0 0 0 1 0]
# 10. Contract Trump rep:  [0 0 1 0 0]
#
# Possible Legal Actions: [TS]
# Final Choice: 83

# %%
if payoffs[0] > payoffs[1]:
    print('Your Team: Won')
else:
    print('Your Team: Lose')
# Out:
# Your Team: Lose
